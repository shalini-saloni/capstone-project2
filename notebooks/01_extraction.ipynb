# %% [markdown]
# # Dataset Sourcing
#
# This notebook documents and validates the source dataset used in the capstone ETL pipeline.

# %%
# Import libraries

import sys
# !{sys.executable} -m pip install pandas
from pathlib import Path

import pandas as pd
# Out:
# Collecting pandas
#   Downloading pandas-3.0.2-cp311-cp311-macosx_10_9_x86_64.whl.metadata (79 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.4.4-cp311-cp311-macosx_14_0_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/shalinisaloni/Library/Python/3.11/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/shalinisaloni/Library/Python/3.11/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.2-cp311-cp311-macosx_10_9_x86_64.whl (10.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 3.2 MB/s  0:00:03m0:00:010:01
# Downloading numpy-2.4.4-cp311-cp311-macosx_14_0_x86_64.whl (6.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 8.2 MB/s  0:00:00 eta 0:00:01
# Installing collected packages: numpy, pandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]2m1/2 [pandas]
# Successfully installed numpy-2.4.4 pandas-3.0.2
#
# [notice] A new release of pip is available: 26.0.1 -> 26.1
# [notice] To update, run: /usr/local/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip

# %%
# Define source path and validate source file

source_path = Path('../data/raw/online_retail.csv')

if not source_path.exists():
    raise FileNotFoundError(f'Source file not found: {source_path.resolve()}')

print(f'Source file found: {source_path.resolve()}')
# Out:
# Source file found: /Users/shalinisaloni/capstone-project2/data/raw/online_retail.csv

# %%
# Load source dataset
# Use ISO-8859-1 encoding for the Online Retail dataset
df_source = pd.read_csv(source_path, encoding='ISO-8859-1')

print(f'Source dataset shape: {df_source.shape}')
# Out:
# Source dataset shape: (541909, 8)

# %%
# Source data preview and schema check

display(df_source.head())
df_source.info()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 0  2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2  2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4  2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# <class 'pandas.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  str
#  1   StockCode    541909 non-null  str
#  2   Description  540455 non-null  str
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  str
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  str
# dtypes: float64(2), int64(1), str(5)
# memory usage: 33.1 MB
